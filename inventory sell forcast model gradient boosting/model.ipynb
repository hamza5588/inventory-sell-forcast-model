# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data=pd.read_csv("/content/online_retail.csv")

# %%
a=data.sample(20000)

# %%
a["Country"].value_counts()
# Out:
# United Kingdom          18370
# Germany                   349
# France                    288
# EIRE                      276
# Netherlands                98
# Spain                      87
# Belgium                    81
# Switzerland                64
# Australia                  53
# Portugal                   44
# Italy                      36
# Norway                     34
# Finland                    27
# Channel Islands            22
# Unspecified                19
# Austria                    18
# Denmark                    17
# Sweden                     17
# Cyprus                     17
# Poland                     13
# Japan                      13
# Hong Kong                   9
# Israel                      9
# Singapore                   7
# USA                         7
# Iceland                     6
# Canada                      5
# Greece                      2
# Malta                       2
# United Arab Emirates        2
# European Community          2
# ...

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# Assuming you have a DataFrame 'df' with features and labels
X = a.drop(['Country'], axis=1)
y = a['Country']

# Random oversampling
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X, y)

# # Random undersampling
# rus = RandomUnderSampler(random_state=42)
# X_resampled, y_resampled = rus.fit_resample(X, y)

# %%
X_resampled
# Out:
#          index InvoiceNo StockCode                          Description  \
# 0            0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1            1    536365     71053                  WHITE METAL LANTERN
# 2            2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3            3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4            4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...        ...       ...       ...                                  ...
# 1098920  46514    540354    85180A              RED HEARTS LIGHT CHAIN
# 1098921  46514    540354    85180A              RED HEARTS LIGHT CHAIN
# 1098922  46514    540354    85180A              RED HEARTS LIGHT CHAIN
# 1098923  46514    540354    85180A              RED HEARTS LIGHT CHAIN
# 1098924  46514    540354    85180A              RED HEARTS LIGHT CHAIN
#
#          Quantity     InvoiceDate  UnitPrice  CustomerID
# ...

# %%
y_resampled.value_counts()
# Out:
# United Kingdom     43957
# Lithuania          43957
# Bahrain            43957
# Finland            43957
# Israel             43957
# Austria            43957
# Sweden             43957
# Cyprus             43957
# Denmark            43957
# Channel Islands    43957
# Iceland            43957
# Japan              43957
# Belgium            43957
# France             43957
# Italy              43957
# Portugal           43957
# Poland             43957
# Spain              43957
# Switzerland        43957
# EIRE               43957
# Norway             43957
# Germany            43957
# Netherlands        43957
# Australia          43957
# United             43957
# Name: Country, dtype: int64

# %%
X_resampled.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1098920     True
# 1098921     True
# 1098922     True
# 1098923     True
# 1098924     True
# Length: 1098925, dtype: bool

# %%
df.groupby('Description')['Total Revenue'].sum().sort_values(ascending=False).head(10).plot(kind='barh')
plt.xlabel('Total Revenue')
plt.ylabel('Product')
plt.title('Top 10 Selling Products')
plt.show()

# %%
monthly_revenue = df.resample('M', on='InvoiceDate')['Total Revenue'].sum()

# %%
#  draw a graph that shows monthly revenue trend

monthly_revenue.plot(figsize=(12, 8))
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.title('Monthly Revenue Trend')
plt.show()

# %%
a.head()
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
a=a.drop(columns=["index"])

# %%
a.isnull().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description      53
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID     5025
# Country           0
# dtype: int64

# %%
a["Description"]=a['Description'].fillna("no description")

# %%
a.isnull().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description       0
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID     5025
# Country           0
# dtype: int64

# %%
a=a.dropna()

# %%
a.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
a.head()
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 531179    580907     23148  MINIATURE ANTIQUE ROSE HOOK IVORY        12
# 254113    559295     22776        SWEETHEART CAKESTAND 3 TIER         1
# 495091    578289     22978                 PANTRY ROLLING PIN         2
# 166016    550836     22607        WOODEN ROUNDERS GARDEN SET          2
# 472869    576770     20750           RED RETROSPOT MINI CASES         2
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 531179   12/6/2011 13:13       0.83     13507.0  United Kingdom
# 254113    7/7/2011 12:32       9.95     12362.0         Belgium
# 495091  11/23/2011 14:07       3.75     17841.0  United Kingdom
# 166016   4/21/2011 10:55       9.95     14759.0  United Kingdom
# 472869  11/16/2011 13:16       7.95     13926.0  United Kingdom

# %%
a.sample(5)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 518771    580117     23199                     JUMBO BAG APPLES        20
# 499558    578678     23266  SET OF 3 WOODEN STOCKING DECORATION         1
# 538895    581420     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 533530    581034     23499          SET 12 VINTAGE DOILY CHALK         24
# 417220    572652     23424              GINGHAM RECIPE BOOK BOX         4
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 518771   12/1/2011 16:28       2.08     14655.0  United Kingdom
# 499558  11/24/2011 19:59       1.25     17841.0  United Kingdom
# 538895   12/8/2011 15:09       2.10     16358.0  United Kingdom
# 533530   12/7/2011 10:48       0.42     17049.0  United Kingdom
# 417220  10/25/2011 12:11       4.95     15805.0  United Kingdom

# %%
sum(not isinstance(x, str) for x in a["StockCode"])
# Out:
# 0

# %%
len(a["StockCode"])
# Out:
# 14975

# %%
a=a[~a['StockCode'].str.contains('[a-zA-Z]')]

# %%
a=a[~a['InvoiceNo'].str.contains('[a-zA-Z]')]

# %%
len(a)
# Out:
# 13373

# %%
# prompt: handle the invoice date also convert into year month day week hour minte sec

a["InvoiceDate"] = pd.to_datetime(a["InvoiceDate"])
a["Year"] = a["InvoiceDate"].dt.year
a["Month"] = a["InvoiceDate"].dt.month
a["Day"] = a["InvoiceDate"].dt.day
a["Hour"] = a["InvoiceDate"].dt.hour
a["Minute"] = a["InvoiceDate"].dt.minute
a["Second"] = a["InvoiceDate"].dt.second
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'InvoiceDate'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
a.drop(columns=["InvoiceDate"],inplace=True)

# %%
x
# Out:
#        InvoiceNo StockCode  Quantity  UnitPrice  CustomerID  Year  Month  Day  \
# 1         536365     71053         6       3.39     17850.0  2010     12    1
# 5         536365     22752         2       7.65     17850.0  2010     12    1
# 6         536365     21730         6       4.25     17850.0  2010     12    1
# 7         536366     22633         6       1.85     17850.0  2010     12    1
# 8         536366     22632         6       1.85     17850.0  2010     12    1
# ...          ...       ...       ...        ...         ...   ...    ...  ...
# 541898    581587     22727         4       3.75     12680.0  2011     12    9
# 541899    581587     22726         4       3.75     12680.0  2011     12    9
# 541900    581587     22730         4       3.75     12680.0  2011     12    9
# 541901    581587     22367         8       1.95     12680.0  2011     12    9
# 541902    581587     22629        12       1.95     12680.0  2011     12    9
#
# ...

# %%
y
# Out:
# 1         35
# 5         35
# 6         35
# 7         35
# 8         35
#           ..
# 541898    13
# 541899    13
# 541900    13
# 541901    13
# 541902    13
# Name: Country, Length: 371014, dtype: int64

# %%
x.shape
# Out:
# (371014, 7)

# %%
y.shape
# Out:
# (371014,)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,shuffle=False)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder

# %%
lencoder=LabelEncoder()

# %%
a["Country"]=lencoder.fit_transform(a["Country"])

# %%
a=pd.get_dummies(a,columns=["Description"])

# %%
x=a.drop(columns=["Country"])
y=a["Country"]

# %%
xtrain
# Out:
#        InvoiceNo StockCode  Quantity  UnitPrice  CustomerID  Year  Month  Day  \
# 531179    580907     23148        12       0.83     13507.0  2011     12    6
# 254113    559295     22776         1       9.95     12362.0  2011      7    7
# 495091    578289     22978         2       3.75     17841.0  2011     11   23
# 166016    550836     22607         2       9.95     14759.0  2011      4   21
# 472869    576770     20750         2       7.95     13926.0  2011     11   16
# ...          ...       ...       ...        ...         ...   ...    ...  ...
# 487749    577778     22469         3       1.65     16549.0  2011     11   21
# 48158     540464     21272        12       1.06     14298.0  2011      1    7
# 509456    579301     22383         2       1.65     18118.0  2011     11   29
# 418468    572726     22960         3       4.25     16056.0  2011     10   25
# 135406    547895     22993         1       1.25     18118.0  2011      3   28
#
# ...

# %%
ytrain
# Out:
# 531179    34
# 254113     3
# 495091    34
# 166016    34
# 472869    34
#           ..
# 487749    34
# 48158     34
# 509456    34
# 418468    34
# 135406    34
# Name: Country, Length: 10928, dtype: int64

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
model=AdaBoostClassifier(n_estimators=200,learning_rate=0.1)

# %%
model.fit(xtrain,ytrain)
# Out:
# AdaBoostClassifier(learning_rate=0.1, n_estimators=200)

# %%
ypredict=model.predict(xtest)

# %%
accurcy=accuracy_score(ytest,ypredict)

# %%
accurcy
# Out:
# 0.914018691588785

# %%
accurcy
# Out:
# 0.9095327102803739
